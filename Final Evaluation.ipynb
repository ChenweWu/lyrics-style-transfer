# %%
import nltk
from tqdm import tqdm
nltk.download('punkt')
from nltk import word_tokenize
from nltk.translate.bleu_score import sentence_bleu
import numpy as np
! pip install sentence_transformers
from sentence_transformers import SentenceTransformer
! pip install bert-score
! pip install transformers datasets
import torch
from transformers import BertTokenizer,BertForMaskedLM, DistilBertTokenizer, DistilBertModel
from transformers import GPT2LMHeadModel, GPT2TokenizerFast, OpenAIGPTTokenizer, OpenAIGPTLMHeadModel
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
#      |████████████████████████████████| 78 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 30.4 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 56.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 50.7 MB/s
# ...
#      |████████████████████████████████| 61 kB 329 kB/s
# ...
#      |████████████████████████████████| 596 kB 46.0 MB/s
# ...
#      |████████████████████████████████| 895 kB 54.9 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=b47343461607673f11f1724d50f44f70156bbf832fc20c1e68bc07bfb912b14a
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
# ...

# %%
# GPT2
device = 'cuda'
model_id = 'gpt2-large'
GPT2model = GPT2LMHeadModel.from_pretrained(model_id).to(device)
GPT2tokenizer = GPT2TokenizerFast.from_pretrained(model_id)
# # GPT
# GPTmodel = OpenAIGPTLMHeadModel.from_pretrained('openai-gpt')
# GPTtokenizer = OpenAIGPTTokenizer.from_pretrained('openai-gpt')
# Out:
# Downloading:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.02G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Pretrained Models

# %% [markdown]
# ## Embedding - GloVe  (not used)

# %%
# cd drive/Shareddrives/'MIT NLP 8.864'/

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove*.zip

# print('Indexing word vectors.')

# embeddings_index = {}
# f = open('glove.6B.100d.txt', encoding='utf-8')
# for line in f:
#     values = line.split()
#     word = values[0]
#     coefs = np.asarray(values[1:], dtype='float32')
#     embeddings_index[word] = coefs
# f.close()

# print('Found %s word vectors.' % len(embeddings_index))

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip -q glove.6B.zip

# path_to_glove_file = os.path.join(
#     os.path.expanduser("~"), ".keras/datasets/glove.6B.100d.txt"
# )

# embeddings_index = {}
# with open(path_to_glove_file) as f:
#     for line in f:
#         word, coefs = line.split(maxsplit=1)
#         coefs = np.fromstring(coefs, "f", sep=" ")
#         embeddings_index[word] = coefs

# print("Found %s word vectors." % len(embeddings_index))

# %%
# embeddings_index = {}

# %%
# with open('glove.6B.200d.txt','r') as f:
#   for line in f:
#       word, coefs = line.split(maxsplit=1)
#       coefs = np.fromstring(coefs, "f", sep=" ")
#       embeddings_dict[word] = coefs

# %%
# len(embeddings_dict)

# %% [markdown]
# ## Embedding - Universal Sentence Encoder

# %%
#@title Load the Universal Sentence Encoder's TF Hub module
from absl import logging

import tensorflow as tf

import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" #@param ["https://tfhub.dev/google/universal-sentence-encoder/4", "https://tfhub.dev/google/universal-sentence-encoder-large/5"]
model = hub.load(module_url)
print ("module %s loaded" % module_url)
def universe_embed(input):
  return model(input)
# Out:
# INFO:absl:Using /tmp/tfhub_modules to cache modules.
# INFO:absl:Downloading TF-Hub Module 'https://tfhub.dev/google/universal-sentence-encoder/4'.
# INFO:absl:Downloaded https://tfhub.dev/google/universal-sentence-encoder/4, Total size: 987.47MB
# INFO:absl:Downloaded TF-Hub Module 'https://tfhub.dev/google/universal-sentence-encoder/4'.
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %% [markdown]
# # Compute Metrics

# %% [markdown]
# ## **BLEU SCORES**:
# self-bleu and geometric mean-bleu

# %%
import nltk
nltk.download('punkt')
from nltk.translate.bleu_score import sentence_bleu,corpus_bleu


## self bleu 
def bleuScore(origs,gens): 
  # list of list of tokenized strings
  # origs = []
  # gens = []

  # for batch in range(len(data): 
  # # for batch in range(2*len(data): 
  #   #to do: (call original line) from data and append each to origs
  #   #to do: (call generated line) from data and append each to gens 
    
  score1 = sentence_bleu(origs, gens, weights=(0,0,0,0))
  score2 = sentence_bleu(origs, gens, weights=(0.5, 0.5, 0, 0))
  score3 = sentence_bleu(origs, gens, weights=(0.33, 0.33, 0.33, 0))
  score4 = sentence_bleu(origs, gens, weights=(0.25, 0.25, 0.25, 0.25))
  
  bleu_score = np.cumsum((score1*score2*score3*score4)**0.25)
  # bleu_score = bleu_score / len(data)
  # bleu_score = bleu_score / (2*len(data))

  return bleu_score*100
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## **BERT SCORE:**
# between source and transferred embeddings

# %%
from datasets import load_metric
metric = load_metric("bertscore")
def bertScore(origs, gens):
  # origs and gens are list of str with same len
  origs = [c for c in origs if c !='']
  gens = [c for c in gens if c !='']
  max_len = max(len(origs),len(gens))
  if len(origs)< max_len:
    for i in range(max_len-len(origs)):
      origs.append('')
  else:
    for i in range(max_len-len(gens)):
      gens.append('')
  return metric.compute(predictions = origs,
                        references=gens,
                        lang="en")['f1']
# Out:
# Downloading:   0%|          | 0.00/2.93k [00:00<?, ?B/s]

# %% [markdown]
# ### Old Bert (not used)

# %%
# pip install bert-score

# %%
## bert score

# from bert_score import score, BERTScorer

# def bertScore(originals, generated): #text sentences
#   scorer = BERTScorer(lang="en", rescale_with_baseline=True)
#   P, R, F1 = scorer.score(generated, originals)

# return F1

# def bertScore(origs, gens): #embeddings
#   # origs = []
#   # gens= []
#   # for batch in range(len(data): 
#   # # for batch in range(2*len(data): 
#   #   #to do: (call original line) from data
#   #   origs.append()
#   #   #to do: (call generated line) from data
#   #   gens.append()
#   _, _, F1 = score(gens, origs, lang="en", rescale_with_baseline=True)
#   print(F1)
#   bertScore = np.cumsum(list(F1.numpy()))/len(list(F1.numpy()))*100

#   return bertScore ,F1

# %% [markdown]
# ## **Cosine Similarity**:
# between source and transferred embeddings
# Embedding Options:
# 1. tf-idf (may be not a good choice because we don't actually have files but only sentences?)
# 2. GloVe
# 3. our trained encoder
# 4. Universal Sentence Encoder (https://colab.research.google.com/github/tensorflow/hub/blob/master/examples/colab/semantic_similarity_with_tf_hub_universal_encoder.ipynb)

# %%
def universal_cosine(ori,gen):
  return torch.cosine_similarity(torch.tensor(universe_embed(ori).numpy()),
                        torch.tensor(universe_embed(gen).numpy()))

# %%
model_sentence_transformer = SentenceTransformer('paraphrase-MiniLM-L6-v2')

def sentence_transformer_cosine(ori, gen):
  ori_embeddings = torch.tensor(model_sentence_transformer.encode(ori))
  gen_embeddings = torch.tensor(model_sentence_transformer.encode(gen))
  return torch.cosine_similarity(ori_embeddings,
                        gen_embeddings)
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/314 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
model_mpnet = SentenceTransformer('all-mpnet-base-v2')

def mpnet_cosine(ori, gen):
  ori_embeddings = torch.tensor(model_mpnet.encode(ori))
  gen_embeddings = torch.tensor(model_mpnet.encode(gen))
  return torch.cosine_similarity(ori_embeddings,
                        gen_embeddings)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
model_distilRB = SentenceTransformer('all-distilroberta-v1')

def distilRB_cosine(ori, gen):
  ori_embeddings = torch.tensor(model_distilRB.encode(ori))
  gen_embeddings = torch.tensor(model_distilRB.encode(gen))
  return torch.cosine_similarity(ori_embeddings,
                        gen_embeddings)
# Out:
# Downloading:   0%|          | 0.00/737 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.86k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/653 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/333 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## **Fluency:**
# general perplexity, data perplexity, and total perplexity
#
# Relevant article:
# https://www.scribendi.ai/comparing-bert-and-gpt-2-as-language-models-to-score-the-grammatical-correctness-of-a-sentence/

# %%
# def id2word(self,indexes):
#   """Convert a list of word indexes to string. Prepare for perplexity.
#   Input: [int]
#   Return: [str]"""
#   result = []
#   for i in indexes:
#     result.append(self.id2v[i])
#   return result

# %% [markdown]
# ### Self model (not used)

# %%
# def perplexity(probs):
#   """probs: (batch, max_len, vocab_size) the probability of each word in each 
#   position of the sentence. 
#     It is also called logits_vectors as the output of decoder"""
#   ppl = [0]*probs.shape[0]
#   sentence_len = probs.shape[1]
#   probs = torch.max(probs, dim = -1)
#   for i in range(probs.shape[0]): 
#     ppl[i] = torch.exp(torch.mean(torch.log(probs[i,:])))
#   return torch.mean(ppl)

# %% [markdown]
# ### Bert - Perplexity
# Colab link: https://colab.research.google.com/github/huggingface/notebooks/blob/master/transformers_doc/quicktour.ipynb
# Documentation link: https://huggingface.co/transformers/model_doc/bert.html#bertformaskedlm

# %%
# Load pre-trained model (weights)
with torch.no_grad():
    bertmodel = BertForMaskedLM.from_pretrained('bert-large-cased')
    bertmodel.eval()
    # Load pre-trained model tokenizer (vocabulary)
    bert_tokenizer = BertTokenizer.from_pretrained('bert-large-cased')
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
def bert_ppl(sentence):
    tokenize_input = bert_tokenizer.tokenize(sentence)
    tokenize_input = ["[CLS]"]+tokenize_input+["[SEP]"]
    tokenized_input=bert_tokenizer.convert_tokens_to_ids(tokenize_input)
    tokenized_inputs = torch.tensor([tokenized_input])
    with torch.no_grad():
        loss=bertmodel(tokenized_inputs, labels = tokenized_inputs)[0]
    return torch.exp(loss.detach())

# %% [markdown]
# ### Pretrained GPT2 - Perplexity
# pretrained GPT : https://huggingface.co/transformers/model_doc/gpt.html#openaigptlmheadmodel
#
# GPT2 perplexity with fixed length instruction: https://huggingface.co/transformers/perplexity.html

# %%
def gpt_ppl(transfered_words, gram_size = 20, 
            tokenizer= GPT2tokenizer, model = GPT2model):
  """
  Calculate the mean perplexity score of sentences returned 
  by the style transfer network. 
  input:
  - `transfered_sents`: a 2d-tensor of shape
      (batch_size, max_len) representing output sentence and
      the corresponding words 
  - `gram_size`: the sliding window size to calculate perplexity score. 
    this is same as the stride in the instruction.
  - `tokenizer`: can be either GPTtokenizer or GPT2tokenizer
      option 1 (GPT2): GPT2TokenizerFast.from_pretrained('gpt2-large')
      option 2 (GPT) : OpenAIGPTTokenizer.from_pretrained('openai-gpt')
  - `model`: which GPT model to generate probability
      option 1 (GPT2): GPT2LMHeadModel.from_pretrained('gpt2-large').to('cuda')
      option 2 (GPT) : OpenAIGPTLMHeadModel.from_pretrained('openai-gpt')
  return:
    - `ppls`: a list of perplexity scores for all sentences
  """

  gpt_max_length = model.config.n_positions 
  ppls = []
  encodings = GPT2tokenizer(transfered_words, return_tensors='pt')
  nlls = []
  for i in tqdm(range(0, encodings.input_ids.size(1), gram_size)):
    
    begin_loc = max(i + gram_size - gpt_max_length, 0)
    end_loc = min(i + gram_size, encodings.input_ids.size(1))
    trg_len = end_loc - i    # may be different from gram_size on last loop
    # print(device)
    input_ids = encodings.input_ids[:,begin_loc:end_loc].to(device)
    target_ids = input_ids.clone()
    target_ids[:,:-trg_len] = -100
    
    with torch.no_grad():
        outputs = model(input_ids, labels=target_ids)
        neg_log_likelihood = outputs[0] * trg_len

    nlls.append(neg_log_likelihood)

  ppl = torch.exp(torch.stack(nlls).sum() / end_loc)
  ppls.append(ppl)
  return ppls

# %% [markdown]
# #### Test old data (not used)

# %%
# !pip install transformers datasets
# from transformers import GPT2LMHeadModel, GPT2TokenizerFast
# from datasets import load_dataset 
# import torch 
# from tqdm import tqdm 

# device = 'cuda'
# model_id = 'gpt2-large'
# model = GPT2LMHeadModel.from_pretrained(model_id).to(device) 
# tokenizer = GPT2TokenizerFast.from_pretrained(model_id) 

# test = load_dataset('wikitext', 'wikitext-2-raw-v1', split='test') 
# encodings = tokenizer('\n\n'.join(test['text']), return_tensors='pt') 
# max_length = model.config.n_positions 

# stride = 2 
# nlls = [] 

# for i in tqdm(range(0, encodings.input_ids.size(1), stride)): 
#     begin_loc = max(i + stride - max_length, 0) 
#     end_loc = min(i + stride, encodings.input_ids.size(1)) 
#     trg_len = end_loc - i 
#     input_ids = encodings.input_ids[:,begin_loc:end_loc].to(device) 
#     target_ids = input_ids.clone() 
#     target_ids[:,:-trg_len] = -100 
#     print(begin_loc,end_loc)

#     with torch.no_grad(): 
#         outputs = model(input_ids, labels=target_ids) 
#         print('here:',i,outputs[0])
#         neg_log_likelihood = outputs[0] * trg_len 
#         print("sop")

#     nlls.append(neg_log_likelihood) 
#     break

# ppl = torch.exp(torch.stack(nlls).sum() / end_loc)

# %%
# nlls = []
# from tqdm import tqdm
# for i in tqdm(range(0, encodings.input_ids.size(1), stride)):
#     begin_loc = max(i + stride - max_length, 0)
#     end_loc = min(i + stride, encodings.input_ids.size(1))
#     trg_len = end_loc - i    # may be different from stride on last loop
#     input_ids = encodings.input_ids[:,begin_loc:end_loc].to(device)
#     target_ids = input_ids.clone()
#     target_ids[:,:-trg_len] = -100

#     with torch.no_grad():
#         outputs = model(input_ids, labels=target_ids)
#         print('here:',i,outputs[0]* trg_len)
#         print(nlls)
#         print("after")
#         neg_log_likelihood = outputs[0] * trg_len

#     nlls.append(neg_log_likelihood)
#     break

# ppl = torch.exp(torch.stack(nlls).sum() / end_loc)

# %% [markdown]
# # All Evaluation

# %%
import os
import json

model_dir = '/content/drive/Shareddrives/MIT NLP 8.864/model'

# TODO: Change model_name
model_name = 'model_7/model_7_20211204_143127'

model_name = os.path.join(model_dir,model_name)
origis_path = os.path.join(model_name,'orig.txt')
tsf_path = os.path.join(model_name,'tsf.txt')
raw_path = os.path.join(model_name,'raw.txt')
origis = []
tsf = []
raw = []
with open(origis_path,'r') as f:
  for l in f.readlines():
    origis.append(eval(l)+[''])
with open(tsf_path,'r') as f:
  for l in f.readlines():
    tsf.append(eval(l)+[''])
with open(raw_path,'r') as f:
  for l in f.readlines():
    raw.append(eval(l))

# %%
# scorer = BERTScorer(lang="en", rescale_with_baseline=True)

def generate_batch_eval(origis,word_output):#,vocab):
  result = []
  not_wanted = ['<s>','<pad>','</s>'] 
  
  def clean_words(x):
    test_list = [t if t not in not_wanted else '' for t in x]
    test_example = ' '.join(test_list) 
    return test_list, test_example

  # def lookup_words(x, vocab):
  #   return [vocab[i] for i in x]


  batch_size = 0
  if type(word_output)==list:
    batch_size = len(word_output)
  else:
    batch_size = word_output.shape[0]
  cosine_universe,cosine_sent_trans,cosine_mpnets = [],[],[]
  cosine_mpnets ,cosine_distils = [],[]
  bert_ppls , gpt_ppls = [],[]
  bertScore_result , bleuScore_result = [] ,[]
  output_lists = []
  raw_lists = []
  for idx in range(batch_size):
    # Clean Words
    # test_example = lookup_words(word_output[idx], vocab)
    test_list, test_example = clean_words(word_output[idx])
    # ori = lookup_words(origis[idx], vocab)
    ori_list, ori = clean_words(origis[idx])
    raw_lists.append(ori)
    output_lists.append(test_example)

    # GPT_PPL
    gpt_ppls +=gpt_ppl(test_example)
    # print("GPT_PPL finished")

    # bert_ppl
    # bert_ppls.append(bert_ppl(test_example))

    # BleuScore
    bleuScore_result.append(bleuScore(ori,test_example))
  print("BleuScore finished")

    

  # cosine similarity - universal 
  cosine_universe=universal_cosine(raw_lists,output_lists)
  print("cosine_universe finished")

  # cosine similarity - sentence_transformer_cosine
  cosine_sent_trans=sentence_transformer_cosine(raw_lists, output_lists)
  print("sentence_transformer_cosine finished")

  # cosine similarity - mpnet_cosine
  cosine_mpnets=mpnet_cosine(raw_lists,output_lists)
  print("cosine_mpnets finished")

  # cosine similarity - distilBert
  cosine_distils=distilRB_cosine(raw_lists, output_lists)
  print("cosine_distils finished")

  # BertScore
  bertScore_result = bertScore(raw_lists, output_lists)
  print("bertScore finished")

  
  all_evals = {"cosine_universal_sentence":cosine_universe,
               "cosine_sent_transformer":cosine_sent_trans,
               "cosine_mpnets":cosine_mpnets,
               "cosine_distils":cosine_distils,
               "ppl_gpt":gpt_ppls,
               "ppl_bert":bert_ppls,
               "bertScore_result":bertScore_result,
               "bleuScore_result":bleuScore_result
               }
  return all_evals

# %%
result_orig = generate_batch_eval(raw,origis)
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 100%|██████████| 1/1 [00:00<00:00, 34.22it/s]
# ...
# ...
# 100%|██████████| 1/1 [00:00<00:00, 30.98it/s]
# BleuScore finished
# cosine_universe finished
# sentence_transformer_cosine finished
# cosine_mpnets finished
# cosine_distils finished
# Downloading:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# bertScore finished

# %%
result_tsf = generate_batch_eval(raw,tsf)
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 100%|██████████| 1/1 [00:00<00:00, 33.85it/s]
# ...
# ...
# 100%|██████████| 1/1 [00:00<00:00, 33.94it/s]
# BleuScore finished
# cosine_universe finished
# sentence_transformer_cosine finished
# cosine_mpnets finished
# cosine_distils finished
# bertScore finished

# %%
# Reconstruction Result
print("reconstructing result")
print("cosine_universal_sentence:",torch.mean(result_orig['cosine_universal_sentence']))
print("cosine_sent_transformer:",torch.mean(result_orig['cosine_sent_transformer']))
print("cosine_mpnets:",torch.mean(result_orig['cosine_mpnets']))
print("cosine_distils:",torch.mean(result_orig['cosine_distils']))
print("ppl_gpt:",torch.mean(torch.tensor(result_orig['ppl_gpt'])))
print("bertScore_result:",np.mean(result_orig['bertScore_result']))
print("bleuScore_result:",np.mean(result_orig['bleuScore_result']))
print()

# Transferred Result
print("transferred result")
print("cosine_universal_sentence:",torch.mean(result_tsf['cosine_universal_sentence']))
print("cosine_sent_transformer:",torch.mean(result_tsf['cosine_sent_transformer']))
print("cosine_mpnets:",torch.mean(result_tsf['cosine_mpnets']))
print("cosine_distils:",torch.mean(result_tsf['cosine_distils']))
print("ppl_gpt:",torch.mean(torch.tensor(result_tsf['ppl_gpt'])))
print("bertScore_result:",np.mean(result_tsf['bertScore_result']))
print("bleuScore_result:",np.mean(result_tsf['bleuScore_result']))

# %%
cosine_universal_sentence = torch.mean(torch.concat([result_orig['cosine_universal_sentence'],
              result_tsf['cosine_universal_sentence']]))
cosine_sent_transformer = torch.mean(torch.concat([result_orig['cosine_sent_transformer'],
              result_tsf['cosine_sent_transformer']]))
cosine_mpnets = torch.mean(torch.concat([result_orig['cosine_mpnets'],
              result_tsf['cosine_mpnets']]))
cosine_distils = torch.mean(torch.concat([result_orig['cosine_distils'],
              result_tsf['cosine_distils']]))
ppl_gpt = torch.mean(torch.tensor(result_orig['ppl_gpt']+result_tsf['ppl_gpt']))
# ppl_bert = np.mean(result_['ppl_bert']+result_['ppl_bert'])
bertScore_result = np.mean(result_orig['bertScore_result']+result_tsf['bertScore_result'])
bleuScore_result = np.mean(result_orig['bleuScore_result']+result_tsf['bleuScore_result'])
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 28.28it/s]

# %%
print("cosine_universal_sentence:",cosine_universal_sentence)
print("cosine_sent_transformer:",cosine_sent_transformer)
print("cosine_mpnets:",cosine_mpnets)
print("cosine_distils:",cosine_distils)
print("ppl_gpt:",ppl_gpt)
print("bertScore_result:",bertScore_result)
print("bleuScore_result:",bleuScore_result)
# Out:
# cosine_universal_sentence: tensor(0.4376)
# cosine_sent_transformer: tensor(0.4680)
# cosine_mpnets: tensor(0.3961)
# cosine_distils: tensor(0.4239)
# ppl_gpt: tensor(119.9742)
# bertScore_result: 0.8622350328415632
# bleuScore_result: 70.62382480791555
